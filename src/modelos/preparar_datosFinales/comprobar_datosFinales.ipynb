# %%
import pandas as pd
import os

# Definimos la ruta donde se guardó el archivo
csv_path = r'C:\Users\PC\Desktop\3ºGIDIA\PD2\PD2-conducIA\data\processed\tlc_clean\csv_final.csv'

# Verificamos si el archivo existe antes de intentar leerlo
if os.path.exists(csv_path):
    # Cargamos el dataset
    df_verificacion = pd.read_csv(csv_path)
    
    print(f"--- PRIMERAS FILAS (Inicio del año/Diciembre anterior) ---")
    display(df_verificacion.head(5))
    
    print(f"\n" + "="*50 + "\n")
    
    print(f"--- ÚLTIMAS FILAS (Final del año actual) ---")
    display(df_verificacion.tail(5))
    
    print(f"\nDimensiones totales del dataset: {df_verificacion.shape[0]:,} filas y {df_verificacion.shape[1]} columnas.")
else:
    print(f"Error: No se encontró el archivo en {csv_path}. Asegúrate de haber ejecutado el script .py primero.")
# Out:
# --- PRIMERAS FILAS (Inicio del año/Diciembre anterior) ---
#           fecha_inicio            fecha_fin  origen_id  destino_id  \
# 0  2024-12-01 00:00:34  2024-12-01 00:10:21        163         229
# 1  2024-12-01 00:00:36  2024-12-01 00:17:36        226         107
# 2  2024-12-01 00:00:50  2024-12-01 00:19:51         56          80
# 3  2024-12-01 00:01:09  2024-12-01 00:22:08        116         162
# 4  2024-12-01 00:01:14  2024-12-01 00:11:02        168         167
#
#    num_pasajeros  distancia  propina  tipo_pago  duracion_min  velocidad_mph  \
# 0            1.0       1.40     3.00        1.0      9.783333       8.586031
# 1            NaN       5.38     6.38        NaN     17.000000      18.988236
# 2            NaN       5.14     0.00        NaN     19.016667      16.217353
# 3            NaN       7.21     0.00        NaN     20.983333      20.616362
# 4            NaN       2.00     0.00        NaN      9.800000      12.244898
#
# ...
