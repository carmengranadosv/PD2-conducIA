# %% [markdown]
# # Comprobación de datos para el dataset_final

# %%
import pandas as pd
import os
import pyarrow.parquet as pq

# Definimos la ruta
parquet_path = os.path.join("..", "..", "..", "data", "processed", "tlc_clean", "datos_final.parquet")

if os.path.exists(parquet_path):
    # 1. Abrimos el archivo como un objeto de Parquet (esto no carga los datos)
    pfile = pq.ParquetFile(parquet_path)
    
    # 2. Obtenemos metadatos generales
    total_filas = pfile.metadata.num_rows
    print(f"Dimensiones totales del dataset: {total_filas:,} filas y {pfile.metadata.num_columns} columnas.")
    
    # 3. Leemos solo los bloques necesarios (el primero y el último)
    # read_row_group(0) lee el bloque inicial, el último es num_row_groups - 1
    df_inicio = pfile.read_row_group(0).to_pandas()
    df_fin = pfile.read_row_group(pfile.num_row_groups - 1).to_pandas()
    
    print(f"\n--- PRIMERAS FILAS (Inicio del periodo) ---")
    display(df_inicio.head(5))
    
    print(f"\n" + "="*50 + "\n")
    
    print(f"--- ÚLTIMAS FILAS (Final del periodo) ---")
    display(df_fin.tail(5))
    
    # Análisis ligero de una columna específica (ej: tipo_vehiculo)
    # Usamos value_counts() sobre un bloque para ver qué hay, sin cargar todo
    print(f"\n--- Muestra de 'tipo_vehiculo' (basada en el primer bloque) ---")
    print(df_inicio['tipo_vehiculo'].value_counts())

else:
    print(f"Error: No se encontró el archivo en la ruta relativa: {parquet_path}")
# Out:
# Dimensiones totales del dataset: 80,539,168 filas y 32 columnas.
#
# --- PRIMERAS FILAS (Inicio del periodo) ---
#   fecha_inicio           fecha_fin  origen_id  destino_id  num_pasajeros  \
# 0   2024-12-01 2024-12-01 00:06:30        144         113              1
# 1   2024-12-01 2024-12-01 00:26:15         71          71              1
# 2   2024-12-01 2024-12-01 00:11:27         36          37              1
# 3   2024-12-01 2024-12-01 00:19:25        148         186              1
# 4   2024-12-01 2024-12-01 00:03:53         89          89              1
#
#    distancia  propina  duracion_min  velocidad_mph tipo_vehiculo  ...  \
# 0       0.98     2.58      6.500000       9.046154   Yellow Taxi  ...
# 1       5.23     4.16     26.250000      11.954286           VTC  ...
# 2       1.52     0.00     11.450000       7.965065           VTC  ...
# 3       2.84     0.00     19.416667       8.775965           VTC  ...
# 4       0.65     0.00      3.883333      10.042918           VTC  ...
#
#    es_festivo  evento_tipo  num_eventos mes_num hora dia_semana es_fin_semana  \
# 0           0       No hay            0      12    0          6             1
# 1           0       No hay            0      12    0          6             1
# 2           0       No hay            0      12    0          6             1
# 3           0       No hay            0      12    0          6             1
# 4           0       No hay            0      12    0          6             1
#
#    franja_horaria  hora_sen  hora_cos
# 0       Madrugada       0.0       1.0
# 1       Madrugada       0.0       1.0
# 2       Madrugada       0.0       1.0
# 3       Madrugada       0.0       1.0
# 4       Madrugada       0.0       1.0
#
# [5 rows x 32 columns]
# ==================================================
#
# --- ÚLTIMAS FILAS (Final del periodo) ---
#               fecha_inicio           fecha_fin  origen_id  destino_id  \
# 847387 2025-11-30 23:59:56 2025-12-01 00:05:55         97          49
# 847388 2025-11-30 23:59:57 2025-12-01 00:20:18         35         256
# 847389 2025-11-30 23:59:57 2025-12-01 00:05:43         79         137
# 847390 2025-11-30 23:59:59 2025-12-01 00:30:10        138         144
# 847391 2025-11-30 23:59:59 2025-12-01 00:16:17        167          74
#
#         num_pasajeros  distancia  propina  duracion_min  velocidad_mph  \
# 847387              1       1.15     0.00      5.983333      11.532033
# 847388              1       4.11     0.00     20.350000      12.117937
# 847389              1       1.07     2.00      5.766667      11.132949
# 847390              1      13.29    14.08     30.183333      26.418553
# 847391              1       3.07     0.00     16.300000      11.300613
#
#        tipo_vehiculo  ...  es_festivo  evento_tipo  num_eventos mes_num hora  \
# 847387           VTC  ...           0       No hay            0      11   23
# 847388           VTC  ...           0       No hay            0      11   23
# 847389   Yellow Taxi  ...           0       No hay            0      11   23
# 847390   Yellow Taxi  ...           0       No hay            0      11   23
# 847391           VTC  ...           0       No hay            0      11   23
#
#        dia_semana es_fin_semana  franja_horaria  hora_sen  hora_cos
# 847387          6             1           Noche -0.258819  0.965926
# 847388          6             1           Noche -0.258819  0.965926
# 847389          6             1           Noche -0.258819  0.965926
# 847390          6             1           Noche -0.258819  0.965926
# 847391          6             1           Noche -0.258819  0.965926
#
# [5 rows x 32 columns]
# --- Muestra de 'tipo_vehiculo' (basada en el primer bloque) ---
# tipo_vehiculo
# VTC            850484
# Yellow Taxi    198092
# Name: count, dtype: int64

# %%
print(f"--- Primeras 20 filas de 'tipo_vehiculo' (Bloque inicial) ---")
print(df_inicio['tipo_vehiculo'].head(20))
# Out:
# --- Primeras 20 filas de 'tipo_vehiculo' (Bloque inicial) ---
# 0     Yellow Taxi
# 1             VTC
# 2             VTC
# 3             VTC
# 4             VTC
# 5             VTC
# 6             VTC
# 7             VTC
# 8             VTC
# 9             VTC
# 10            VTC
# 11            VTC
# 12            VTC
# 13            VTC
# 14    Yellow Taxi
# 15            VTC
# 16            VTC
# 17            VTC
# 18            VTC
# 19            VTC
# Name: tipo_vehiculo, dtype: str

# %% [markdown]
# # Comprobación de datos para datos_final

# %% [markdown]
# Estos son los datos limpios, con los que trabajaremos en los modelos

# %%
import pandas as pd
import os
import pyarrow.parquet as pq

# Ruta al archivo limpio que generamos
parquet_path = os.path.join("..", "..", "..", "data", "processed", "tlc_clean", "datos_final.parquet")

if os.path.exists(parquet_path):
    # 1. Inspección de metadatos (sin cargar el archivo a RAM)
    pfile = pq.ParquetFile(parquet_path)
    print(f"Archivo encontrado: {os.path.basename(parquet_path)}")
    print(f"Total de registros: {pfile.metadata.num_rows:,}")
    
    # 2. Cargar una muestra representativa para verificar la limpieza
    df_muestra = pfile.read_row_group(0).to_pandas()
    
    print("\n--- COMPROBACIÓN DE LA LIMPIEZA ---")
    
    # A) ¿tipo_pago ha desaparecido?
    if 'tipo_pago' not in df_muestra.columns:
        print("Columna 'tipo_pago': ELIMINADA correctamente.")
    else:
        print("Error: 'tipo_pago' sigue presente.")
        
    # B) ¿Quedan nulos en las columnas críticas?
    nulos_prop = df_muestra['propina'].isna().sum()
    nulos_pas = df_muestra['num_pasajeros'].isna().sum()
    
    print(f"Nulos en 'propina': {nulos_prop}")
    print(f"Nulos en 'num_pasajeros': {nulos_pas}")
    
    # 3. Vista rápida de datos
    print("\n--- VISTA PREVIA (Primeras 5 filas) ---")
    display(df_muestra[['propina', 'num_pasajeros']].head())
    
    # 4. Estadísticas rápidas para ver si la imputación funcionó
    print("\n--- ESTADÍSTICAS MUESTRALES ---")
    print(df_muestra[['propina', 'num_pasajeros']].describe())

else:
    print(f"Error: No se encontró el archivo en: {parquet_path}")
# Out:
# Archivo encontrado: datos_final.parquet
# Total de registros: 80,539,168
#
# --- COMPROBACIÓN DE LA LIMPIEZA ---
# Columna 'tipo_pago': ELIMINADA correctamente.
# Nulos en 'propina': 0
# Nulos en 'num_pasajeros': 0
#
# --- VISTA PREVIA (Primeras 5 filas) ---
#    propina  num_pasajeros
# 0     2.58              1
# 1     4.16              1
# 2     0.00              1
# 3     0.00              1
# 4     0.00              2
# --- ESTADÍSTICAS MUESTRALES ---
#             propina  num_pasajeros
# count  1.048576e+06      1048576.0
# mean   1.792351e+00       1.276115
# std    3.669451e+00        0.73359
# min    0.000000e+00            0.0
# 25%    0.000000e+00            1.0
# 50%    0.000000e+00            1.0
# 75%    2.940000e+00            1.0
# max    1.000000e+02            6.0

# %% [markdown]
# Comprobar si el dataset está ordenado cronológicamente

# %%
# --- COMPROBACIÓN DE ORDEN CRONOLÓGICO ---
print("\n--- COMPROBACIÓN DE ORDEN ---")

# Asumiendo que tu columna de fecha se llama 'fecha_inicio'
# Si tiene otro nombre (ej: 'pickup_datetime'), cámbialo abajo:
columna_fecha = 'fecha_inicio' 

if columna_fecha in df_muestra.columns:
    # Verificamos si los datos del primer bloque están ordenados
    esta_ordenado = df_muestra[columna_fecha].is_monotonic_increasing
    
    if esta_ordenado:
        print(f"El dataset está ordenado cronológicamente por '{columna_fecha}'.")
    else:
        print(f"El dataset NO parece estar ordenado por '{columna_fecha}'.")
        print(f"Primeras fechas del bloque:\n{df_muestra[columna_fecha].head()}")
else:
    print(f"No se encontró la columna '{columna_fecha}' para verificar el orden.")
# Out:
# --- COMPROBACIÓN DE ORDEN ---
# El dataset está ordenado cronológicamente por 'fecha_inicio'.

# %%
# --- VISTA EXTENDIDA: PRIMERAS 30 FILAS ---
print("\n--- VISTA EXTENDIDA (Primeras 30 filas) ---")

# En lugar de cargar todo el archivo, leemos solo el primer grupo de filas (row group)
# y extraemos las primeras 30
df_muestra_30 = pfile.read_row_group(0).to_pandas().head(30)

# Mostramos el resultado
display(df_muestra_30)
# Out:
# --- VISTA EXTENDIDA (Primeras 30 filas) ---
#           fecha_inicio           fecha_fin  origen_id  destino_id  \
# 0  2024-12-01 00:00:00 2024-12-01 00:06:30        144         113
# 1  2024-12-01 00:00:00 2024-12-01 00:26:15         71          71
# 2  2024-12-01 00:00:00 2024-12-01 00:11:27         36          37
# 3  2024-12-01 00:00:00 2024-12-01 00:19:25        148         186
# 4  2024-12-01 00:00:00 2024-12-01 00:03:53         89          89
# 5  2024-12-01 00:00:00 2024-12-01 00:09:43        188         189
# 6  2024-12-01 00:00:00 2024-12-01 00:16:26         56         260
# 29              1   0.660000   5.000000      7.233333       5.474655
#
#    tipo_vehiculo  ...  destino_barrio  temp_c  precipitation viento_kmh  \
# 0    Yellow Taxi  ...       Manhattan    -2.0            0.0       10.3
# 1            VTC  ...        Brooklyn    -1.8            0.0       10.9
# 2            VTC  ...        Brooklyn    -1.8            0.0       10.9
# 3            VTC  ...       Manhattan    -2.0            0.0       10.3
# 4            VTC  ...        Brooklyn    -1.8            0.0       10.9
# 5            VTC  ...        Brooklyn    -1.8            0.0       10.9
# 6            VTC  ...          Queens    -2.1            0.0        9.3
# 7            VTC  ...          Queens    -2.1            0.0        9.3
# 8            VTC  ...       Manhattan    -1.6            0.0       11.7
# 9            VTC  ...       Manhattan    -1.8            0.0       10.9
# 10           VTC  ...       Manhattan    -2.0            0.0       10.3
# 11           VTC  ...           Bronx    -1.6            0.0       11.7
# 12           VTC  ...        Brooklyn    -1.8            0.0       10.9
# 13           VTC  ...          Queens    -2.1            0.0        9.3
# 14   Yellow Taxi  ...       Manhattan    -2.0            0.0       10.3
# 15           VTC  ...           Bronx    -2.1            0.0        9.3
# 16           VTC  ...           Bronx    -1.8            0.0       10.9
# 17           VTC  ...          Queens    -2.1            0.0        9.3
# 18           VTC  ...          Queens    -2.1            0.0        9.3
# 19           VTC  ...        Brooklyn    -2.0            0.0       10.3
# 20           VTC  ...        Brooklyn    -1.8            0.0       10.9
# 21           VTC  ...       Manhattan    -2.0            0.0       10.3
# 22           VTC  ...        Brooklyn    -2.1            0.0        9.3
# 23           VTC  ...          Queens    -2.1            0.0        9.3
# 24           VTC  ...        Brooklyn    -1.8            0.0       10.9
# 25           VTC  ...       Manhattan    -2.0            0.0       10.3
# 26           VTC  ...          Queens    -2.1            0.0        9.3
# 27           VTC  ...           Bronx    -2.0            0.0       10.3
# 28           VTC  ...       Manhattan    -2.0            0.0       10.3
# 29           VTC  ...       Manhattan    -2.0            0.0       10.3
#
#    lluvia nieve es_festivo  evento_tipo  num_eventos  mes_num
# 0       0     0          0       No hay            0       12
# 1       0     0          0       No hay            0       12
# 2       0     0          0       No hay            0       12
# 3       0     0          0       No hay            0       12
# 4       0     0          0       No hay            0       12
# 5       0     0          0       No hay            0       12
# 6       0     0          0       No hay            0       12
# 7       0     0          0       No hay            0       12
# 8       0     0          0       No hay            0       12
# 9       0     0          0       No hay            0       12
# 10      0     0          0       No hay            0       12
# 11      0     0          0       No hay            0       12
# 12      0     0          0       No hay            0       12
# 13      0     0          0       No hay            0       12
# 14      0     0          0       No hay            0       12
# 15      0     0          0       No hay            0       12
# 16      0     0          0       No hay            0       12
# 17      0     0          0       No hay            0       12
# 18      0     0          0       No hay            0       12
# 19      0     0          0       No hay            0       12
# 20      0     0          0       No hay            0       12
# 21      0     0          0       No hay            0       12
# 22      0     0          0       No hay            0       12
# 23      0     0          0       No hay            0       12
# 24      0     0          0       No hay            0       12
# 25      0     0          0       No hay            0       12
# 26      0     0          0       No hay            0       12
# 27      0     0          0       No hay            0       12
# 28      0     0          0       No hay            0       12
# 29      0     0          0       No hay            0       12
#
# [30 rows x 26 columns]
