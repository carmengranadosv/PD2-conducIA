# %% [markdown]
# # Comprobación de datos para el dataset_final

# %%
import pandas as pd
import os
import pyarrow.parquet as pq

# Definimos la ruta
parquet_path = os.path.join("..", "..", "..", "data", "processed", "tlc_clean", "dataset_final.parquet")

if os.path.exists(parquet_path):
    # 1. Abrimos el archivo como un objeto de Parquet (esto no carga los datos)
    pfile = pq.ParquetFile(parquet_path)
    
    # 2. Obtenemos metadatos generales
    total_filas = pfile.metadata.num_rows
    print(f"Dimensiones totales del dataset: {total_filas:,} filas y {pfile.metadata.num_columns} columnas.")
    
    # 3. Leemos solo los bloques necesarios (el primero y el último)
    # read_row_group(0) lee el bloque inicial, el último es num_row_groups - 1
    df_inicio = pfile.read_row_group(0).to_pandas()
    df_fin = pfile.read_row_group(pfile.num_row_groups - 1).to_pandas()
    
    print(f"\n--- PRIMERAS FILAS (Inicio del periodo) ---")
    display(df_inicio.head(5))
    
    print(f"\n" + "="*50 + "\n")
    
    print(f"--- ÚLTIMAS FILAS (Final del periodo) ---")
    display(df_fin.tail(5))
    
    # Análisis ligero de una columna específica (ej: tipo_vehiculo)
    # Usamos value_counts() sobre un bloque para ver qué hay, sin cargar todo
    print(f"\n--- Muestra de 'tipo_vehiculo' (basada en el primer bloque) ---")
    print(df_inicio['tipo_vehiculo'].value_counts())

else:
    print(f"Error: No se encontró el archivo en la ruta relativa: {parquet_path}")
# Out:
# Dimensiones totales del dataset: 80,539,168 filas y 27 columnas.
#
# --- PRIMERAS FILAS (Inicio del periodo) ---
#   fecha_inicio           fecha_fin  origen_id  destino_id  num_pasajeros  \
# 0   2024-12-01 2024-12-01 00:06:30        144         113              1
# 1   2024-12-01 2024-12-01 00:26:15         71          71           <NA>
# 2   2024-12-01 2024-12-01 00:11:27         36          37           <NA>
# 3   2024-12-01 2024-12-01 00:19:25        148         186           <NA>
# 4   2024-12-01 2024-12-01 00:03:53         89          89           <NA>
#
#    distancia  propina  tipo_pago  duracion_min  velocidad_mph  ...  \
# 0       0.98     2.58        1.0      6.500000       9.046154  ...
# 1       5.23     4.16        NaN     26.250000      11.954286  ...
# 2       1.52     0.00        NaN     11.450000       7.965065  ...
# 3       2.84     0.00        NaN     19.416667       8.775965  ...
# 4       0.65     0.00        NaN      3.883333      10.042918  ...
#
#   destino_barrio  temp_c  precipitation  viento_kmh lluvia nieve es_festivo  \
# 0      Manhattan    -2.0            0.0        10.3      0     0          0
# 1       Brooklyn    -1.8            0.0        10.9      0     0          0
# 2       Brooklyn    -1.8            0.0        10.9      0     0          0
# 3      Manhattan    -2.0            0.0        10.3      0     0          0
# 4       Brooklyn    -1.8            0.0        10.9      0     0          0
#
#   evento_tipo  num_eventos  mes_num
# 0      No hay            0       12
# 1      No hay            0       12
# 2      No hay            0       12
# 3      No hay            0       12
# 4      No hay            0       12
#
# [5 rows x 27 columns]
# ==================================================
#
# --- ÚLTIMAS FILAS (Final del periodo) ---
#               fecha_inicio           fecha_fin  origen_id  destino_id  \
# 847387 2025-11-30 23:59:56 2025-12-01 00:05:55         97          49
# 847388 2025-11-30 23:59:57 2025-12-01 00:20:18         35         256
# 847389 2025-11-30 23:59:57 2025-12-01 00:05:43         79         137
# 847390 2025-11-30 23:59:59 2025-12-01 00:30:10        138         144
# 847391 2025-11-30 23:59:59 2025-12-01 00:16:17        167          74
#
#         num_pasajeros  distancia  propina  tipo_pago  duracion_min  \
# 847387           <NA>       1.15     0.00        NaN      5.983333
# 847388           <NA>       4.11     0.00        NaN     20.350000
# 847389              1       1.07     2.00        1.0      5.766667
# 847390              1      13.29    14.08        1.0     30.183333
# 847391           <NA>       3.07     0.00        NaN     16.300000
#
#         velocidad_mph  ... destino_barrio  temp_c  precipitation  viento_kmh  \
# 847387      11.532033  ...       Brooklyn     4.2            0.0        13.6
# 847388      12.117937  ...       Brooklyn     4.2            0.0        13.6
# 847389      11.132949  ...      Manhattan     4.0            0.0        14.5
# 847390      26.418553  ...      Manhattan     4.0            0.0        11.4
# 847391      11.300613  ...      Manhattan     4.1            0.0        15.1
#
#        lluvia nieve es_festivo evento_tipo  num_eventos  mes_num
# 847387      0     0          0      No hay            0       11
# 847388      0     0          0      No hay            0       11
# 847389      0     0          0      No hay            0       11
# 847390      0     0          0      No hay            0       11
# 847391      0     0          0      No hay            0       11
#
# [5 rows x 27 columns]
# --- Muestra de 'tipo_vehiculo' (basada en el primer bloque) ---
# tipo_vehiculo
# VTC            850484
# Yellow Taxi    198092
# Name: count, dtype: int64

# %%
print(f"--- Primeras 20 filas de 'tipo_vehiculo' (Bloque inicial) ---")
print(df_inicio['tipo_vehiculo'].head(20))
# Out:
# --- Primeras 20 filas de 'tipo_vehiculo' (Bloque inicial) ---
# 0     Yellow Taxi
# 1             VTC
# 2             VTC
# 3             VTC
# 4             VTC
# 5             VTC
# 6             VTC
# 7             VTC
# 8             VTC
# 9             VTC
# 10            VTC
# 11            VTC
# 12            VTC
# 13            VTC
# 14    Yellow Taxi
# 15            VTC
# 16            VTC
# 17            VTC
# 18            VTC
# 19            VTC
# Name: tipo_vehiculo, dtype: str

# %% [markdown]
# # Comprobación de datos para datos_final

# %% [markdown]
# Estos son los datos limpios, con los que trabajaremos en los modelos

# %%
import pandas as pd
import os
import pyarrow.parquet as pq

# Ruta al archivo limpio que generamos
parquet_path = os.path.join("..", "..", "..", "data", "processed", "tlc_clean", "datos_final.parquet")

if os.path.exists(parquet_path):
    # 1. Inspección de metadatos (sin cargar el archivo a RAM)
    pfile = pq.ParquetFile(parquet_path)
    print(f"Archivo encontrado: {os.path.basename(parquet_path)}")
    print(f"Total de registros: {pfile.metadata.num_rows:,}")
    
    # 2. Cargar una muestra representativa para verificar la limpieza
    df_muestra = pfile.read_row_group(0).to_pandas()
    
    print("\n--- COMPROBACIÓN DE LA LIMPIEZA ---")
    
    # A) ¿tipo_pago ha desaparecido?
    if 'tipo_pago' not in df_muestra.columns:
        print("Columna 'tipo_pago': ELIMINADA correctamente.")
    else:
        print("Error: 'tipo_pago' sigue presente.")
        
    # B) ¿Quedan nulos en las columnas críticas?
    nulos_prop = df_muestra['propina'].isna().sum()
    nulos_pas = df_muestra['num_pasajeros'].isna().sum()
    
    print(f"Nulos en 'propina': {nulos_prop}")
    print(f"Nulos en 'num_pasajeros': {nulos_pas}")
    
    # 3. Vista rápida de datos
    print("\n--- VISTA PREVIA (Primeras 5 filas) ---")
    display(df_muestra[['propina', 'num_pasajeros']].head())
    
    # 4. Estadísticas rápidas para ver si la imputación funcionó
    print("\n--- ESTADÍSTICAS MUESTRALES ---")
    print(df_muestra[['propina', 'num_pasajeros']].describe())

else:
    print(f"Error: No se encontró el archivo en: {parquet_path}")
# Out:
# Archivo encontrado: datos_final.parquet
# Total de registros: 80,539,168
#
# --- COMPROBACIÓN DE LA LIMPIEZA ---
# Columna 'tipo_pago': ELIMINADA correctamente.
# Nulos en 'propina': 0
# Nulos en 'num_pasajeros': 0
#
# --- VISTA PREVIA (Primeras 5 filas) ---
#    propina  num_pasajeros
# 0     2.58              1
# 1     4.16              1
# 2     0.00              1
# 3     0.00              1
# 4     0.00              2
# --- ESTADÍSTICAS MUESTRALES ---
#             propina  num_pasajeros
# count  1.048576e+06      1048576.0
# mean   1.792351e+00       1.276115
# std    3.669451e+00        0.73359
# min    0.000000e+00            0.0
# 25%    0.000000e+00            1.0
# 50%    0.000000e+00            1.0
# 75%    2.940000e+00            1.0
# max    1.000000e+02            6.0
